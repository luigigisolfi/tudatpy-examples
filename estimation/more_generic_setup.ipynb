# %% [markdown]
# ## Objectives
#
# This script allows to download:
# 1) spice kernels
# 2) odf and ifms files (closed/open loop data)
# 3) ancillary files such as tropospheric and ionospheric data
#
# List of Supported input_missions (this list will grow):
#
# - JUICE
# - MRO
# - LRO
# - GRAIL
# - Insight
# - Cassini

# %%
# Load required standard modules
import multiprocessing as mp
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# Load required tudatpy modules
from tudatpy import constants
from tudatpy.io import save2txt
# from tudatpy.io import grail_mass_level_0_file_reader
# from tudatpy.io import grail_antenna_file_reader
from tudatpy.interface import spice
from tudatpy import numerical_simulation
from tudatpy.astro import time_conversion
from tudatpy.astro import frame_conversion
from tudatpy.astro import element_conversion
from tudatpy.math import interpolators
from tudatpy.numerical_simulation import environment_setup
from tudatpy.numerical_simulation import propagation
from tudatpy.numerical_simulation.environment_setup import radiation_pressure
from tudatpy.numerical_simulation import propagation_setup
from tudatpy.numerical_simulation import estimation, estimation_setup
from tudatpy.numerical_simulation import create_dynamics_simulator
from tudatpy.numerical_simulation.estimation_setup import observation
from tudatpy import util
# Out:
# /var/folders/vw/h3bwl54d4h9fxt45xnkxm86jgk0dgk/T/ipykernel_22409/1516825575.py:11: DeprecationWarning: Importing from the `tudatpy.io` module is deprecated since tudatpy 0.7 and will raise an error two minor versions hence. To eliminate this warning import from `tudatpy.data` instead.
#   from tudatpy.io import save2txt

# %%
from more_generic_load_pds_files import download_url_files_time, dynamic_download_url_files_time_interval
from datetime import datetime, timedelta
from urllib.request import urlretrieve

from more_generic_load_pds_files_class import *

# %%
object = LoadPDS()

# %%
current_directory = os.getcwd()

# %%
#EXAMPLE OF ADDING A CUSTOMIZED PATTERN FOR USER DOWNLOADING!
object.add_custom_mission_pattern('luigi', 'blabla')
# Out:
# {'juice': '^(?:([a-z]+)_)?(?:([a-z]+)_)?(?:([a-z]+)_)?(\\d{6})_(\\d{6})(?:_s(\\d{6}))?(?:_(v\\d+))?(\\.bc)$',
#  'mex': '^(?P<data>ATNM)_(?P<purpose>MEASURED)_(?P<start_date_file>\\d{6})_(?P<end_date_file>\\d{6})_(?P<version>(V\\d+))?(?P<extension>\\.BC)$',
#  'mro': '^(?P<mission>mro)_(?P<instrument>[a-z]+)(?:_(?P<purpose>[a-z]+))?_(?P<start_date_file>\\d{6})_(?P<end_date_file>\\d{6})(?P<extension>\\.bc)$',
#  'lro': '^(lro)([a-z]+)?(?:_([a-z]+))?_(\\d{6}|\\d{7})_(\\d{6}|\\d{7})(?:_(s\\d{6}))?(?:_(v\\d+))?(\\.bc)$',
#  'cassini': '^(?:([a-zA-Z0-9]+)_)?(\\d{5})_(\\d{5})([a-z]{0,2})?(\\.bc)$',
#  'luigi': ('blabla', 'luigi')}

# %%
# Test examples Orientation Files
MRO_dict = object.Orientation.parse_orientation_filename("mro", "mro_hga_psp_060311_060331.bc")

#JUICE_dict = object.Orientation.parse_orientation_filename("juice", "juice_mga_meas_230701_230719_s230628_v01.bc")
#LRO_dict = object.Orientation.parse_orientation_filename("lro", "lrosc_2009186_2009213_v01.bc")
MEX_dict = object.Orientation.parse_orientation_filename("mex","ATNM_MEASURED_100101_110101_V03.BC")
#CASSINI_dict = object.Orientation.parse_orientation_filename("cassini", "00017_00024rb.bc")

#print(object.Orientation.reconstruct_orientation_filename("juice",JUICE_dict))
print(object.Orientation.reconstruct_orientation_filename("mro",MRO_dict))
#print(object.Orientation.reconstruct_orientation_filename("lro",LRO_dict))
print(object.Orientation.reconstruct_orientation_filename("mex",MEX_dict))
#print(object.Orientation.reconstruct_orientation_filename("cassini", CASSINI_dict))
# Out:
# {'mission': 'mro', 'instrument': 'hga', 'purpose': 'psp', 'start_date_file': '060311', 'end_date_file': '060331', 'extension': '.bc'}
# {'data': 'ATNM', 'purpose': 'MEASURED', 'start_date_file': '100101', 'end_date_file': '110101', 'version': 'V03', 'extension': '.BC'}
# mro_hga_psp_060311_060331.bc
# ATNM_MEASURED_100101_110101_V03.BC

# %%
# Test examples Orientation Files
##JUICE_IFMS_dict = object.Orientation.parse_orientation_filename("juice", "juice_mga_meas_230701_230719_s230628_v01.bc")
#MRO_IFMS_dict = object.Orientation.parse_orientation_filename("mro", "mro_hga_psp_060311_060331.bc")
#LRO_IFMS_dict = object.Orientation.parse_orientation_filename("lro", "lrosc_2009186_2009213_v01.bc")
MRO_IFMS_dict = object.IFMS.parse_IFMS_filename("mro","mromagr2006_242_0216xmmmv1.odf")
print(MRO_IFMS_dict)
print(object.IFMS.reconstruct_IFMS_filename("mro",MRO_IFMS_dict))
MEX_IFMS_dict = object.IFMS.parse_IFMS_filename("mex","m32icl1l02_d2x_031801831_00.tab")
print(MEX_IFMS_dict)
#CASSINI_IFMS_dict = object.Orientation.parse_orientation_filename("cassini", "00017_00024rb.bc")

##print(object.Orientation.reconstruct_orientation_filename("juice",JUICE_IFMS_dict))
#print(object.Orientation.reconstruct_orientation_filename("mro",MRO_IFMS_dict))
#print(object.Orientation.reconstruct_orientation_filename("lro",LRO_IFMS_dict))
print(object.IFMS.reconstruct_IFMS_filename("mex",MEX_IFMS_dict))
#print(object.Orientation.reconstruct_orientation_filename("cassini", CASSINI_IFMS_dict))
# Out:
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_242_0216', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_242_0216', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 8, 30, 2, 16)}
# mromagr2006_242_0216xmmmv1.odf
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801831', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801831', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 18, 31)}
# m32icl1l02_d2x_031801831_00.tab

# %%
def get_mex_files(local_path, start_date, end_date):
    input_mission = 'mex'
    print(type(start_date),type(end_date))
    all_dates = [start_date+timedelta(days=x) for x in range((end_date-start_date).days+1)]

    # Clock files
    print('---------------------------------------------')
    print('Download MEX clock files')
    clock_files=["mex_041215_step.tsc"] #latest mex tsc file
    url_clock_files="https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/extras/ancillary/spice/sclk/"
    for file in clock_files:
        if ( os.path.exists(local_path+file) == False ):
            print('download', local_path+file)
            urlretrieve(url_clock_files+file, local_path+file)

    print('relevant clock files')
    for k in range(len(clock_files)):
        clock_files[ k ] = local_path+clock_files[k]
        print(clock_files[k])

    # Orientation files
    print('---------------------------------------------')
    print('Download MEX orientation kernels')
    url_orientation_files = "https://spiftp.esac.esa.int/data/SPICE/MARS-EXPRESS/kernels/ck/"
    orientation_files_to_load = object.dynamic_download_url_files_time_interval(input_mission, 
        local_path=local_path, filename_format='ATNM_MEASURED_*.BC', start_date=start_date,end_date=end_date,
        url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')
    
    #print('---------------------------------------------')
    #print('Download MEX Solar Array kernels')
    #antenna_files_to_load = object.try_dynamic_download_url_files_time_interval(
    #    local_path=local_path, filename_format='juice_sa_meas_*.bc', start_date=start_date,end_date=end_date,
    #    url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')

    #for file in antenna_files_to_load:
    #    orientation_files_to_load.append(file)

    #print('relevant orientation files')
    #for f in orientation_files_to_load:
    #    print(f)


    # # Tropospheric corrections
    # print('---------------------------------------------')
    # print('Download JUICE tropospheric corrections files')
    # url_tro_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/tro/"
    # tro_files_to_load = download_url_files_time_interval(
    #     local_path=local_path, filename_format='mromagr*.tro', start_date=start_date,
    #     end_date=end_date, url=url_tro_files, time_interval_format='%Y_%j_%Y_%j' )

    # print('relevant tropospheric corrections files')
    # for f in tro_files_to_load:
    #     print(f)


    # # Ionospheric corrections
    # print('---------------------------------------------')
    # print('Download JUICE ionospheric corrections files')
    # url_ion_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/ion/"
    # ion_files_to_load = download_url_files_time_interval(local_path=local_path, filename_format='mromagr*.ion', start_date=start_date,
    #                                  end_date=end_date, url=url_ion_files, time_interval_format='%Y_%j_%Y_%j' )

    # print('relevant ionospheric corrections files')
    # for f in ion_files_to_load:
    #     print(f)


    # IFMS files
    print('---------------------------------------------')
    print('Download MEX IFMS files')
    url_ifms = ("https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/")
    ifms_files_to_load = object.dynamic_download_url_files_single_time(input_mission, 
        local_path, 'm32icl*.tab', start_date, end_date,
        url_ifms,'%y%j%H%M')

    print('relevant IFMS files')
    for f in ifms_files_to_load:
        print(f)

    return ifms_files_to_load, clock_files, orientation_files_to_load #, tro_files_to_load, ion_files_to_load

# %%
def get_juice_files(local_path, start_date, end_date):
    input_mission = 'JUICE'
    all_dates = [start_date+timedelta(days=x) for x in range((end_date-start_date).days+1)]

    # Clock files
    print('---------------------------------------------')
    print('Download JUICE clock files')
    clock_files=["juice_step_20160326_v03.tsc"] #latest juice tsc file
    url_clock_files="https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/sclk/"
    for file in clock_files:
        if ( os.path.exists(local_path+file) == False ):
            print('download', local_path+file)
            urlretrieve(url_clock_files+file, local_path+file)

    print('relevant clock files')
    for k in range(len(clock_files)):
        clock_files[ k ] = local_path+clock_files[k]
        print(clock_files[k])

    # Orientation files
    print('---------------------------------------------')
    print('Download JUICE orientation kernels')
    url_orientation_files = "https://spiftp.esac.esa.int/data/SPICE/JUICE/kernels/ck/"
    orientation_files_to_load = object.dynamic_download_url_files_time_interval(input_mission,
        local_path=local_path, filename_format='juice_sc_meas_*.bc', start_date=start_date,end_date=end_date,
        url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')
    
    print('---------------------------------------------')
    print('Download JUICE Solar Array kernels')
    antenna_files_to_load = object.dynamic_download_url_files_time_interval(input_mission,
        local_path=local_path, filename_format='juice_sa_meas_*.bc', start_date=start_date,end_date=end_date,
        url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')

    for file in antenna_files_to_load:
        orientation_files_to_load.append(file)

    #print('relevant orientation files')
    #for f in orientation_files_to_load:
    #    print(f)


    # # Tropospheric corrections
    # print('---------------------------------------------')
    # print('Download JUICE tropospheric corrections files')
    # url_tro_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/tro/"
    # tro_files_to_load = download_url_files_time_interval(
    #     local_path=local_path, filename_format='mromagr*.tro', start_date=start_date,
    #     end_date=end_date, url=url_tro_files, time_interval_format='%Y_%j_%Y_%j' )

    # print('relevant tropospheric corrections files')
    # for f in tro_files_to_load:
    #     print(f)


    # # Ionospheric corrections
    # print('---------------------------------------------')
    # print('Download JUICE ionospheric corrections files')
    # url_ion_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/ion/"
    # ion_files_to_load = download_url_files_time_interval(local_path=local_path, filename_format='mromagr*.ion', start_date=start_date,
    #                                  end_date=end_date, url=url_ion_files, time_interval_format='%Y_%j_%Y_%j' )

    # print('relevant ionospheric corrections files')
    # for f in ion_files_to_load:
    #     print(f)


    # IFMS files
    # print('---------------------------------------------')
    # print('Download JUICE IFMS files')
    # url_odf = ("https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/")
    # odf_files_to_load = download_url_files_time(
    #     local_path=local_path, filename_format='mromagr*_\w\w\w\wxmmmv1.odf', start_date=start_date,
    #     end_date=end_date, url=url_odf, time_format='%Y_%j', filename_size=30, indices_date_filename=[7])

    # print('relevant odf files')
    # for f in odf_files_to_load:
    #     print(f)

    return clock_files, orientation_files_to_load #, tro_files_to_load, ion_files_to_load, odf_files_to_load

# %%
def get_mro_files(local_path, start_date, end_date):
    input_mission = 'mro'
    all_dates = [start_date+timedelta(days=x) for x in range((end_date-start_date).days+1)]

    # Clock files
    print('---------------------------------------------')
    print('Download MRO clock files')
    clock_files=["mro_sclkscet_00112_65536.tsc"]
    url_clock_files="https://naif.jpl.nasa.gov/pub/naif/pds/data/mro-m-spice-6-v1.0/mrosp_1000/data/sclk/"
    for file in clock_files:
        if ( os.path.exists(local_path+file) == False ):
            print('download', local_path+file)
            urlretrieve(url_clock_files+file, local_path+file)

    print('relevant clock files')
    for k in range(len(clock_files)):
        clock_files[ k ] = local_path+clock_files[k]
        print(clock_files[k])

    # Orientation files
    print('---------------------------------------------')
    print('Download MRO orientation kernels')
    url_orientation_files = "https://naif.jpl.nasa.gov/pub/naif/pds/data/mro-m-spice-6-v1.0/mrosp_1000/data/ck/"
    orientation_files_to_load = object.dynamic_download_url_files_time_interval(input_mission,
        local_path=local_path, filename_format='mro_sc_psp_*.bc', start_date=start_date,end_date=end_date,
        url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')
    print('Download MRO High Gain Antenna kernels')
    antenna_files_to_load = object.dynamic_download_url_files_time_interval(input_mission,
        local_path=local_path, filename_format='mro_hga_psp_*.bc', start_date=start_date,end_date=end_date,
        url=url_orientation_files, time_interval_format='%y%m%d_%y%m%d')

    for file in antenna_files_to_load:
        orientation_files_to_load.append(file)

    print('relevant orientation files')
    for f in orientation_files_to_load:
        print(f)


    # Tropospheric corrections
    #print('---------------------------------------------')
    #print('Download MRO tropospheric corrections files')
    #url_tro_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/tro/"
    #tro_files_to_load = object.dynamic_download_url_files_time_interval(input_mission,
    #    local_path=local_path, filename_format='mromagr*.tro', start_date=start_date,
    #    end_date=end_date, url=url_tro_files, time_interval_format='%Y_%j_%Y_%j')

    #print('relevant tropospheric corrections files')
    #for f in tro_files_to_load:
    #    print(f)
        
    # Ionospheric corrections
    #print('---------------------------------------------')
    #print('Download MRO ionospheric corrections files')
    #url_ion_files = "https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/ancillary/ion/"
    #ion_files_to_load = object.dynamic_download_url_files_time_interval(input_mission, local_path=local_path, filename_format='mromagr*.ion', start_date=start_date,
    #                                end_date=end_date, url=url_ion_files, time_interval_format='%Y_%j_%Y_%j' )

    #print('relevant ionospheric corrections files')
    #for f in ion_files_to_load:
    #    print(f)


    # ODF files
    print('---------------------------------------------')
    print('Download MRO ODF files')
    url_odf = ("https://pds-geosciences.wustl.edu/mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/")
    odf_files_to_load = object.dynamic_download_url_files_single_time(input_mission,
        local_path=local_path, filename_format='mromagr*.odf', start_date=start_date,
        end_date=end_date, url=url_odf, time_format='%Y_%j')

    print('relevant odf files')
    for f in odf_files_to_load:
        print(f)

    return clock_files, orientation_files_to_load, odf_files_to_load

# %%
if __name__ == "__main__":
    
    print('Start')
    inputs = []

    start_date_juice = datetime(2023, 7, 1)
    end_date_juice = datetime(2023, 7, 10)
    
    start_date_mro = datetime(2007, 1, 3)
    end_date_mro = datetime(2007, 1, 5)

    start_date_mex = datetime(2003, 1, 1)
    end_date_mex = datetime(2004, 1, 10) 
    clock_files_to_load_mro, orientation_files_to_load_mro, odf_files_to_load_mro = get_mro_files("mro_kernels/", start_date_mro, end_date_mro)         
    clock_files_to_load_mex, orientation_files_to_load_mex, ifms_files_to_load_mro = get_mex_files("mex_kernels/", start_date_mex, end_date_mex)         
        
    #clock_files_to_load_juice, orientation_files_to_load_juice = get_juice_files("juice_kernels/", start_date_juice, end_date_juice)         
    
    #clock_files_to_load_mro, orientation_files_to_load_mro, tro_files_to_load_mro, ion_files_to_load_mro, odf_files_to_load_mro = \
    #    get_mro_files("mro_kernels/", start_date_mro, end_date_mro)
# Out:
# Start
# ---------------------------------------------
# Download MRO clock files
# relevant clock files
# mro_kernels/mro_sclkscet_00112_65536.tsc
# ---------------------------------------------
# Download MRO orientation kernels
# {'mission': 'mro', 'instrument': 'sc', 'purpose': 'psp', 'start_date_file': '070102', 'end_date_file': '070108', 'extension': '.bc'}
# Done.
# Download MRO High Gain Antenna kernels
# {'mission': 'mro', 'instrument': 'hga', 'purpose': 'psp', 'start_date_file': '070102', 'end_date_file': '070108', 'extension': '.bc'}
# Done.
# relevant orientation files
# mro_kernels/mro_sc_psp_070102_070108.bc
# mro_kernels/mro_hga_psp_070102_070108.bc
# ---------------------------------------------
# Download MRO ODF files
# Error parsing ODF filename mromagr2007_004_1801xmmmv1.odf: 'LoadPDS' object has no attribute 'ODF'
# Error parsing ODF filename mromagr2007_003_0845xmmmv1.odf: 'LoadPDS' object has no attribute 'ODF'
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/
# This is a full URL.
#
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_242_0216xmmmv1.lbl
# This is a full URL.
# mromagr2006_242_0216xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_242_0216xmmmv1.odf
# This is a full URL.
# mromagr2006_242_0216xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_242_0216', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_242_0216', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 8, 30, 2, 16)}
# mromagr2006_242_0216xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_244_0800xmmmv1.lbl
# This is a full URL.
# mromagr2006_244_0800xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_244_0800xmmmv1.odf
# This is a full URL.
# mromagr2006_244_0800xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_244_0800', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_244_0800', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 1, 8, 0)}
# mromagr2006_244_0800xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_244_1553xmmmv1.lbl
# This is a full URL.
# mromagr2006_244_1553xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_244_1553xmmmv1.odf
# This is a full URL.
# mromagr2006_244_1553xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_244_1553', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_244_1553', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 1, 15, 53)}
# mromagr2006_244_1553xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_246_0150xmmmv1.lbl
# This is a full URL.
# mromagr2006_246_0150xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_246_0150xmmmv1.odf
# This is a full URL.
# mromagr2006_246_0150xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_246_0150', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_246_0150', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 3, 1, 50)}
# mromagr2006_246_0150xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_247_0750xmmmv1.lbl
# This is a full URL.
# mromagr2006_247_0750xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_247_0750xmmmv1.odf
# This is a full URL.
# mromagr2006_247_0750xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_247_0750', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_247_0750', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 4, 7, 50)}
# mromagr2006_247_0750xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_248_1828xmmmv1.lbl
# This is a full URL.
# mromagr2006_248_1828xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_248_1828xmmmv1.odf
# This is a full URL.
# mromagr2006_248_1828xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_248_1828', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_248_1828', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 5, 18, 28)}
# mromagr2006_248_1828xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_250_0147xmmmv1.lbl
# This is a full URL.
# mromagr2006_250_0147xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_250_0147xmmmv1.odf
# This is a full URL.
# mromagr2006_250_0147xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_250_0147', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_250_0147', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 7, 1, 47)}
# mromagr2006_250_0147xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_251_0741xmmmv1.lbl
# This is a full URL.
# mromagr2006_251_0741xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_251_0741xmmmv1.odf
# This is a full URL.
# mromagr2006_251_0741xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_251_0741', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_251_0741', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 8, 7, 41)}
# mromagr2006_251_0741xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_252_1724xmmmv1.lbl
# This is a full URL.
# mromagr2006_252_1724xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_252_1724xmmmv1.odf
# This is a full URL.
# mromagr2006_252_1724xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_252_1724', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_252_1724', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 9, 17, 24)}
# mromagr2006_252_1724xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_254_0142xmmmv1.lbl
# This is a full URL.
# mromagr2006_254_0142xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_254_0142xmmmv1.odf
# This is a full URL.
# mromagr2006_254_0142xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_254_0142', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_254_0142', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 11, 1, 42)}
# mromagr2006_254_0142xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_255_0826xmmmv1.lbl
# This is a full URL.
# mromagr2006_255_0826xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_255_0826xmmmv1.odf
# This is a full URL.
# mromagr2006_255_0826xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_255_0826', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_255_0826', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 12, 8, 26)}
# mromagr2006_255_0826xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_256_1507xmmmv1.lbl
# This is a full URL.
# mromagr2006_256_1507xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_256_1507xmmmv1.odf
# This is a full URL.
# mromagr2006_256_1507xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_256_1507', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_256_1507', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 13, 15, 7)}
# mromagr2006_256_1507xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_258_0150xmmmv1.lbl
# This is a full URL.
# mromagr2006_258_0150xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_258_0150xmmmv1.odf
# This is a full URL.
# mromagr2006_258_0150xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_258_0150', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_258_0150', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 15, 1, 50)}
# mromagr2006_258_0150xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_258_2121xmmmv1.lbl
# This is a full URL.
# mromagr2006_258_2121xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_258_2121xmmmv1.odf
# This is a full URL.
# mromagr2006_258_2121xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_258_2121', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_258_2121', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 15, 21, 21)}
# mromagr2006_258_2121xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_260_0802xmmmv1.lbl
# This is a full URL.
# mromagr2006_260_0802xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_260_0802xmmmv1.odf
# This is a full URL.
# mromagr2006_260_0802xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_260_0802', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_260_0802', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 17, 8, 2)}
# mromagr2006_260_0802xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_261_1739xmmmv1.lbl
# This is a full URL.
# mromagr2006_261_1739xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_261_1739xmmmv1.odf
# This is a full URL.
# mromagr2006_261_1739xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_261_1739', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_261_1739', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 18, 17, 39)}
# mromagr2006_261_1739xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_263_0130xmmmv1.lbl
# This is a full URL.
# mromagr2006_263_0130xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_263_0130xmmmv1.odf
# This is a full URL.
# mromagr2006_263_0130xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_263_0130', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_263_0130', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 20, 1, 30)}
# mromagr2006_263_0130xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_264_0745xmmmv1.lbl
# This is a full URL.
# mromagr2006_264_0745xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_264_0745xmmmv1.odf
# This is a full URL.
# mromagr2006_264_0745xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_264_0745', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_264_0745', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 21, 7, 45)}
# mromagr2006_264_0745xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_265_1713xmmmv1.lbl
# This is a full URL.
# mromagr2006_265_1713xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_265_1713xmmmv1.odf
# This is a full URL.
# mromagr2006_265_1713xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_265_1713', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_265_1713', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 22, 17, 13)}
# mromagr2006_265_1713xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_266_2251xmmmv1.lbl
# This is a full URL.
# mromagr2006_266_2251xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_266_2251xmmmv1.odf
# This is a full URL.
# mromagr2006_266_2251xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_266_2251', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_266_2251', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 23, 22, 51)}
# mromagr2006_266_2251xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_268_0740xmmmv1.lbl
# This is a full URL.
# mromagr2006_268_0740xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_268_0740xmmmv1.odf
# This is a full URL.
# mromagr2006_268_0740xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_268_0740', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_268_0740', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 25, 7, 40)}
# mromagr2006_268_0740xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_269_1725xmmmv1.lbl
# This is a full URL.
# mromagr2006_269_1725xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_269_1725xmmmv1.odf
# This is a full URL.
# mromagr2006_269_1725xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_269_1725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_269_1725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 26, 17, 25)}
# mromagr2006_269_1725xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_270_2059xmmmv1.lbl
# This is a full URL.
# mromagr2006_270_2059xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_270_2059xmmmv1.odf
# This is a full URL.
# mromagr2006_270_2059xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_270_2059', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_270_2059', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 27, 20, 59)}
# mromagr2006_270_2059xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_272_0751xmmmv1.lbl
# This is a full URL.
# mromagr2006_272_0751xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_272_0751xmmmv1.odf
# This is a full URL.
# mromagr2006_272_0751xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_272_0751', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_272_0751', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 29, 7, 51)}
# mromagr2006_272_0751xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_273_1725xmmmv1.lbl
# This is a full URL.
# mromagr2006_273_1725xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_273_1725xmmmv1.odf
# This is a full URL.
# mromagr2006_273_1725xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_273_1725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_273_1725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 9, 30, 17, 25)}
# mromagr2006_273_1725xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_275_0018xmmmv1.lbl
# This is a full URL.
# mromagr2006_275_0018xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_275_0018xmmmv1.odf
# This is a full URL.
# mromagr2006_275_0018xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_275_0018', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_275_0018', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 2, 0, 18)}
# mromagr2006_275_0018xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_276_0755xmmmv1.lbl
# This is a full URL.
# mromagr2006_276_0755xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_276_0755xmmmv1.odf
# This is a full URL.
# mromagr2006_276_0755xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_276_0755', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_276_0755', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 3, 7, 55)}
# mromagr2006_276_0755xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_277_1454xmmmv1.lbl
# This is a full URL.
# mromagr2006_277_1454xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_277_1454xmmmv1.odf
# This is a full URL.
# mromagr2006_277_1454xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_277_1454', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_277_1454', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 4, 14, 54)}
# mromagr2006_277_1454xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_279_0031xmmmv1.lbl
# This is a full URL.
# mromagr2006_279_0031xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_279_0031xmmmv1.odf
# This is a full URL.
# mromagr2006_279_0031xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_279_0031', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_279_0031', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 6, 0, 31)}
# mromagr2006_279_0031xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_280_0048xmmmv1.lbl
# This is a full URL.
# mromagr2006_280_0048xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_280_0048xmmmv1.odf
# This is a full URL.
# mromagr2006_280_0048xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_280_0048', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_280_0048', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 7, 0, 48)}
# mromagr2006_280_0048xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_281_0730xmmmv1.lbl
# This is a full URL.
# mromagr2006_281_0730xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_281_0730xmmmv1.odf
# This is a full URL.
# mromagr2006_281_0730xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_281_0730', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_281_0730', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 8, 7, 30)}
# mromagr2006_281_0730xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_283_0138xmmmv1.lbl
# This is a full URL.
# mromagr2006_283_0138xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_283_0138xmmmv1.odf
# This is a full URL.
# mromagr2006_283_0138xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_283_0138', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_283_0138', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 10, 1, 38)}
# mromagr2006_283_0138xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_284_2037xmmmv1.lbl
# This is a full URL.
# mromagr2006_284_2037xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_284_2037xmmmv1.odf
# This is a full URL.
# mromagr2006_284_2037xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_284_2037', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_284_2037', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 11, 20, 37)}
# mromagr2006_284_2037xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_286_2020xmmmv1.lbl
# This is a full URL.
# mromagr2006_286_2020xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_286_2020xmmmv1.odf
# This is a full URL.
# mromagr2006_286_2020xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_286_2020', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_286_2020', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 13, 20, 20)}
# mromagr2006_286_2020xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_289_0718xmmmv1.lbl
# This is a full URL.
# mromagr2006_289_0718xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_289_0718xmmmv1.odf
# This is a full URL.
# mromagr2006_289_0718xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_289_0718', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_289_0718', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 16, 7, 18)}
# mromagr2006_289_0718xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_291_1511xmmmv1.lbl
# This is a full URL.
# mromagr2006_291_1511xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_291_1511xmmmv1.odf
# This is a full URL.
# mromagr2006_291_1511xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_291_1511', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_291_1511', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 18, 15, 11)}
# mromagr2006_291_1511xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_293_0725xmmmv1.lbl
# This is a full URL.
# mromagr2006_293_0725xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_293_0725xmmmv1.odf
# This is a full URL.
# mromagr2006_293_0725xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_293_0725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_293_0725', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 20, 7, 25)}
# mromagr2006_293_0725xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_296_1315xmmmv1.lbl
# This is a full URL.
# mromagr2006_296_1315xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_296_1315xmmmv1.odf
# This is a full URL.
# mromagr2006_296_1315xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_296_1315', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_296_1315', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 23, 13, 15)}
# mromagr2006_296_1315xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_298_0752xmmmv1.lbl
# This is a full URL.
# mromagr2006_298_0752xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_298_0752xmmmv1.odf
# This is a full URL.
# mromagr2006_298_0752xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_298_0752', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_298_0752', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 25, 7, 52)}
# mromagr2006_298_0752xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_300_1434xmmmv1.lbl
# This is a full URL.
# mromagr2006_300_1434xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_300_1434xmmmv1.odf
# This is a full URL.
# mromagr2006_300_1434xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_300_1434', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_300_1434', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 27, 14, 34)}
# mromagr2006_300_1434xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_303_1315xmmmv1.lbl
# This is a full URL.
# mromagr2006_303_1315xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_303_1315xmmmv1.odf
# This is a full URL.
# mromagr2006_303_1315xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_303_1315', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_303_1315', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 10, 30, 13, 15)}
# mromagr2006_303_1315xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_305_0140xmmmv1.lbl
# This is a full URL.
# mromagr2006_305_0140xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_305_0140xmmmv1.odf
# This is a full URL.
# mromagr2006_305_0140xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_305_0140', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_305_0140', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 1, 1, 40)}
# mromagr2006_305_0140xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_307_0715xmmmv1.lbl
# This is a full URL.
# mromagr2006_307_0715xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_307_0715xmmmv1.odf
# This is a full URL.
# mromagr2006_307_0715xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_307_0715', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_307_0715', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 3, 7, 15)}
# mromagr2006_307_0715xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_308_0714xmmmv1.lbl
# This is a full URL.
# mromagr2006_308_0714xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_308_0714xmmmv1.odf
# This is a full URL.
# mromagr2006_308_0714xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_308_0714', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_308_0714', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 4, 7, 14)}
# mromagr2006_308_0714xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_310_0737xmmmv1.lbl
# This is a full URL.
# mromagr2006_310_0737xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_310_0737xmmmv1.odf
# This is a full URL.
# mromagr2006_310_0737xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_310_0737', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_310_0737', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 6, 7, 37)}
# mromagr2006_310_0737xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_311_1537xmmmv1.lbl
# This is a full URL.
# mromagr2006_311_1537xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_311_1537xmmmv1.odf
# This is a full URL.
# mromagr2006_311_1537xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_311_1537', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_311_1537', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 7, 15, 37)}
# mromagr2006_311_1537xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_313_2022xmmmv1.lbl
# This is a full URL.
# mromagr2006_313_2022xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_313_2022xmmmv1.odf
# This is a full URL.
# mromagr2006_313_2022xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_313_2022', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_313_2022', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 9, 20, 22)}
# mromagr2006_313_2022xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_315_1931xmmmv1.lbl
# This is a full URL.
# mromagr2006_315_1931xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_315_1931xmmmv1.odf
# This is a full URL.
# mromagr2006_315_1931xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_315_1931', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_315_1931', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 11, 19, 31)}
# mromagr2006_315_1931xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_317_0840xmmmv1.lbl
# This is a full URL.
# mromagr2006_317_0840xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_317_0840xmmmv1.odf
# This is a full URL.
# mromagr2006_317_0840xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_317_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_317_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 13, 8, 40)}
# mromagr2006_317_0840xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_318_1423xmmmv1.lbl
# This is a full URL.
# mromagr2006_318_1423xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_318_1423xmmmv1.odf
# This is a full URL.
# mromagr2006_318_1423xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_318_1423', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_318_1423', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 14, 14, 23)}
# mromagr2006_318_1423xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_319_2318xmmmv1.lbl
# This is a full URL.
# mromagr2006_319_2318xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_319_2318xmmmv1.odf
# This is a full URL.
# mromagr2006_319_2318xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_319_2318', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_319_2318', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 15, 23, 18)}
# mromagr2006_319_2318xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_321_1540xmmmv1.lbl
# This is a full URL.
# mromagr2006_321_1540xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_321_1540xmmmv1.odf
# This is a full URL.
# mromagr2006_321_1540xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_321_1540', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_321_1540', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 17, 15, 40)}
# mromagr2006_321_1540xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_323_0840xmmmv1.lbl
# This is a full URL.
# mromagr2006_323_0840xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_323_0840xmmmv1.odf
# This is a full URL.
# mromagr2006_323_0840xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_323_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_323_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 19, 8, 40)}
# mromagr2006_323_0840xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_324_0948xmmmv1.lbl
# This is a full URL.
# mromagr2006_324_0948xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_324_0948xmmmv1.odf
# This is a full URL.
# mromagr2006_324_0948xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_324_0948', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_324_0948', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 20, 9, 48)}
# mromagr2006_324_0948xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_325_1503xmmmv1.lbl
# This is a full URL.
# mromagr2006_325_1503xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_325_1503xmmmv1.odf
# This is a full URL.
# mromagr2006_325_1503xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_325_1503', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_325_1503', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 21, 15, 3)}
# mromagr2006_325_1503xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_327_0848xmmmv1.lbl
# This is a full URL.
# mromagr2006_327_0848xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_327_0848xmmmv1.odf
# This is a full URL.
# mromagr2006_327_0848xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_327_0848', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_327_0848', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 23, 8, 48)}
# mromagr2006_327_0848xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_328_1910xmmmv1.lbl
# This is a full URL.
# mromagr2006_328_1910xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_328_1910xmmmv1.odf
# This is a full URL.
# mromagr2006_328_1910xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_328_1910', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_328_1910', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 24, 19, 10)}
# mromagr2006_328_1910xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_330_1045xmmmv1.lbl
# This is a full URL.
# mromagr2006_330_1045xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_330_1045xmmmv1.odf
# This is a full URL.
# mromagr2006_330_1045xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_330_1045', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_330_1045', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 26, 10, 45)}
# mromagr2006_330_1045xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_331_0840xmmmv1.lbl
# This is a full URL.
# mromagr2006_331_0840xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_331_0840xmmmv1.odf
# This is a full URL.
# mromagr2006_331_0840xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_331_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_331_0840', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 27, 8, 40)}
# mromagr2006_331_0840xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_333_1609xmmmv1.lbl
# This is a full URL.
# mromagr2006_333_1609xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_333_1609xmmmv1.odf
# This is a full URL.
# mromagr2006_333_1609xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_333_1609', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_333_1609', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 11, 29, 16, 9)}
# mromagr2006_333_1609xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_335_0225xmmmv1.lbl
# This is a full URL.
# mromagr2006_335_0225xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_335_0225xmmmv1.odf
# This is a full URL.
# mromagr2006_335_0225xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_335_0225', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_335_0225', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 1, 2, 25)}
# mromagr2006_335_0225xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_336_0950xmmmv1.lbl
# This is a full URL.
# mromagr2006_336_0950xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_336_0950xmmmv1.odf
# This is a full URL.
# mromagr2006_336_0950xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_336_0950', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_336_0950', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 2, 9, 50)}
# mromagr2006_336_0950xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_338_0125xmmmv1.lbl
# This is a full URL.
# mromagr2006_338_0125xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_338_0125xmmmv1.odf
# This is a full URL.
# mromagr2006_338_0125xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_338_0125', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_338_0125', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 4, 1, 25)}
# mromagr2006_338_0125xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_340_0405xmmmv1.lbl
# This is a full URL.
# mromagr2006_340_0405xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_340_0405xmmmv1.odf
# This is a full URL.
# mromagr2006_340_0405xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_340_0405', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_340_0405', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 6, 4, 5)}
# mromagr2006_340_0405xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_341_1700xmmmv1.lbl
# This is a full URL.
# mromagr2006_341_1700xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_341_1700xmmmv1.odf
# This is a full URL.
# mromagr2006_341_1700xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_341_1700', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_341_1700', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 7, 17, 0)}
# mromagr2006_341_1700xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_342_1420xmmmv1.lbl
# This is a full URL.
# mromagr2006_342_1420xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_342_1420xmmmv1.odf
# This is a full URL.
# mromagr2006_342_1420xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_342_1420', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_342_1420', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 8, 14, 20)}
# mromagr2006_342_1420xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_343_1901xmmmv1.lbl
# This is a full URL.
# mromagr2006_343_1901xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_343_1901xmmmv1.odf
# This is a full URL.
# mromagr2006_343_1901xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_343_1901', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_343_1901', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 9, 19, 1)}
# mromagr2006_343_1901xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_345_0247xmmmv1.lbl
# This is a full URL.
# mromagr2006_345_0247xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_345_0247xmmmv1.odf
# This is a full URL.
# mromagr2006_345_0247xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_345_0247', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_345_0247', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf', 'date_utc': datetime.datetime(2006, 12, 11, 2, 47)}
# mromagr2006_345_0247xmmmv1.odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_345_2023xmmmv1.lbl
# This is a full URL.
# mromagr2006_345_2023xmmmv1.lbl
# mromagr
# .odf
# Full link: /mro/mro-m-rss-1-magr-v1/mrors_0xxx/odf/mromagr2006_345_2023xmmmv1.odf
# This is a full URL.
# mromagr2006_345_2023xmmmv1.odf
# mromagr
# .odf
# {'mission': 'mro', 'dataset': 'magr', 'date_file': '2006_345_2023', 'uplink': 'x', 'station': 'mm', 'downlink': 'm', 'version': 'v1', 'extension': '.odf'}
# ...
# This is a relative path.
# MEX_SA_231101_231114_S231025_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231101_231127_S231025_V0001.BC
# This is a relative path.
# MEX_SA_231101_231127_S231025_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231101_231130_S231205_V0001.BC
# This is a relative path.
# MEX_SA_231101_231130_S231205_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231201_231206_S231205_V0001.BC
# This is a relative path.
# MEX_SA_231201_231206_S231205_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231201_231213_S231205_V0001.BC
# This is a relative path.
# MEX_SA_231201_231213_S231205_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231201_231220_S231218_V0001.BC
# This is a relative path.
# MEX_SA_231201_231220_S231218_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231201_231227_S231225_V0001.BC
# This is a relative path.
# MEX_SA_231201_231227_S231225_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_231201_231231_S231225_V0001.BC
# This is a relative path.
# MEX_SA_231201_231231_S231225_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240101_S231225_V0001.BC
# This is a relative path.
# MEX_SA_240101_240101_S231225_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240103_S231225_V0001.BC
# This is a relative path.
# MEX_SA_240101_240103_S231225_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240110_S231225_V0001.BC
# This is a relative path.
# MEX_SA_240101_240110_S231225_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240117_S240117_V0001.BC
# This is a relative path.
# MEX_SA_240101_240117_S240117_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240124_S240117_V0001.BC
# This is a relative path.
# MEX_SA_240101_240124_S240117_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240101_240131_S240117_V0001.BC
# This is a relative path.
# MEX_SA_240101_240131_S240117_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240201_240207_S240205_V0001.BC
# This is a relative path.
# MEX_SA_240201_240207_S240205_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240201_240214_S240205_V0001.BC
# This is a relative path.
# MEX_SA_240201_240214_S240205_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240201_240221_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240201_240221_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240201_240228_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240201_240228_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240201_240229_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240201_240229_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240301_240306_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240301_240306_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240301_240313_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240301_240313_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240301_240320_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240301_240320_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240301_240327_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240301_240327_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240301_240331_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240301_240331_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240401_240403_S240215_V0001.BC
# This is a relative path.
# MEX_SA_240401_240403_S240215_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240401_240410_S240409_V0001.BC
# This is a relative path.
# MEX_SA_240401_240410_S240409_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240401_240424_S240422_V0001.BC
# This is a relative path.
# MEX_SA_240401_240424_S240422_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240401_240430_S240430_V0001.BC
# This is a relative path.
# MEX_SA_240401_240430_S240430_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240501_S240430_V0001.BC
# This is a relative path.
# MEX_SA_240501_240501_S240430_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240508_S240430_V0001.BC
# This is a relative path.
# MEX_SA_240501_240508_S240430_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240515_S240430_V0001.BC
# This is a relative path.
# MEX_SA_240501_240515_S240430_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240522_S240430_V0001.BC
# This is a relative path.
# MEX_SA_240501_240522_S240430_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240529_S240528_V0001.BC
# This is a relative path.
# MEX_SA_240501_240529_S240528_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240501_240531_S240528_V0001.BC
# This is a relative path.
# MEX_SA_240501_240531_S240528_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240602_240605_S240528_V0001.BC
# This is a relative path.
# MEX_SA_240602_240605_S240528_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240602_240612_S240528_V0001.BC
# This is a relative path.
# MEX_SA_240602_240612_S240528_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240602_240619_S240528_V0001.BC
# This is a relative path.
# MEX_SA_240602_240619_S240528_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240602_240626_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240602_240626_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240602_240630_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240602_240630_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240701_240703_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240701_240703_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240701_240710_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240701_240710_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240701_240717_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240701_240717_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240701_240724_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240701_240724_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240701_240731_S240626_V0001.BC
# This is a relative path.
# MEX_SA_240701_240731_S240626_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240801_240807_S240807_V0001.BC
# This is a relative path.
# MEX_SA_240801_240807_S240807_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240801_240814_S240807_V0001.BC
# This is a relative path.
# MEX_SA_240801_240814_S240807_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240801_240821_S240821_V0001.BC
# This is a relative path.
# MEX_SA_240801_240821_S240821_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240801_240828_S240821_V0001.BC
# This is a relative path.
# MEX_SA_240801_240828_S240821_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240801_240831_S240904_V0001.BC
# This is a relative path.
# MEX_SA_240801_240831_S240904_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240901_240904_S240904_V0001.BC
# This is a relative path.
# MEX_SA_240901_240904_S240904_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240901_240911_S240904_V0001.BC
# This is a relative path.
# MEX_SA_240901_240911_S240904_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240901_240918_S240918_V0001.BC
# This is a relative path.
# MEX_SA_240901_240918_S240918_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240901_240925_S240918_V0001.BC
# This is a relative path.
# MEX_SA_240901_240925_S240918_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_240901_240930_S240918_V0001.BC
# This is a relative path.
# MEX_SA_240901_240930_S240918_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_241001_241002_S240918_V0001.BC
# This is a relative path.
# MEX_SA_241001_241002_S240918_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_241001_241009_S241004_V0001.BC
# This is a relative path.
# MEX_SA_241001_241009_S241004_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: MEX_SA_241001_241016_S241004_V0001.BC
# This is a relative path.
# MEX_SA_241001_241016_S241004_V0001.BC
# ATNM_MEASURED_
# .BC
# Full link: aareadme.txt
# This is a relative path.
# aareadme.txt
# ATNM_MEASURED_
# .BC
# Full link: former_versions/
# This is a full URL.
#
# ATNM_MEASURED_
# .BC
# Done.
# ---------------------------------------------
# Download MEX IFMS files
# file extension is .tab
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031802351', 'version': '00', 'extension': '.tab'}
# Expected filename to download: m32icl3l02_d2s_031802351_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/
# This is a full URL.
#
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031801831_00.lbl
# This is a full URL.
# m32icl1l02_d2x_031801831_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031801831_00.tab
# This is a full URL.
# m32icl1l02_d2x_031801831_00.tab
# m32icl
# .tab
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801831', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801831', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 18, 31)}
# m32icl1l02_d2x_031801831_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031801944_00.lbl
# This is a full URL.
# m32icl1l02_d2x_031801944_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031801944_00.tab
# This is a full URL.
# m32icl1l02_d2x_031801944_00.tab
# m32icl
# .tab
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801944', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031801944', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 19, 44)}
# m32icl1l02_d2x_031801944_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031802147_00.lbl
# This is a full URL.
# m32icl1l02_d2x_031802147_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031802147_00.tab
# This is a full URL.
# m32icl1l02_d2x_031802147_00.tab
# m32icl
# .tab
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031802147', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031802147', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 21, 47)}
# m32icl1l02_d2x_031802147_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031802349_00.lbl
# This is a full URL.
# m32icl1l02_d2x_031802349_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl1l02_d2x_031802349_00.tab
# This is a full URL.
# m32icl1l02_d2x_031802349_00.tab
# m32icl
# .tab
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031802349', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl1l02', 'band': 'd2x', 'date_file': '031802349', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 23, 49)}
# m32icl1l02_d2x_031802349_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031801838_00.lbl
# This is a full URL.
# m32icl2l02_d2x_031801838_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031801838_00.tab
# This is a full URL.
# m32icl2l02_d2x_031801838_00.tab
# m32icl
# .tab
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031801838', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031801838', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 18, 38)}
# m32icl2l02_d2x_031801838_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031801945_00.lbl
# This is a full URL.
# m32icl2l02_d2x_031801945_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031801945_00.tab
# This is a full URL.
# m32icl2l02_d2x_031801945_00.tab
# m32icl
# .tab
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031801945', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031801945', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 19, 45)}
# m32icl2l02_d2x_031801945_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031802148_00.lbl
# This is a full URL.
# m32icl2l02_d2x_031802148_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031802148_00.tab
# This is a full URL.
# m32icl2l02_d2x_031802148_00.tab
# m32icl
# .tab
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031802148', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031802148', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 21, 48)}
# m32icl2l02_d2x_031802148_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031802350_00.lbl
# This is a full URL.
# m32icl2l02_d2x_031802350_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl2l02_d2x_031802350_00.tab
# This is a full URL.
# m32icl2l02_d2x_031802350_00.tab
# m32icl
# .tab
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031802350', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl2l02', 'band': 'd2x', 'date_file': '031802350', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 23, 50)}
# m32icl2l02_d2x_031802350_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031801837_00.lbl
# This is a full URL.
# m32icl3l02_d2s_031801837_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031801837_00.tab
# This is a full URL.
# m32icl3l02_d2s_031801837_00.tab
# m32icl
# .tab
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031801837', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031801837', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 18, 37)}
# m32icl3l02_d2s_031801837_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031801944_00.lbl
# This is a full URL.
# m32icl3l02_d2s_031801944_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031801944_00.tab
# This is a full URL.
# m32icl3l02_d2s_031801944_00.tab
# m32icl
# .tab
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031801944', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031801944', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 19, 44)}
# m32icl3l02_d2s_031801944_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031802146_00.lbl
# This is a full URL.
# m32icl3l02_d2s_031802146_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031802146_00.tab
# This is a full URL.
# m32icl3l02_d2s_031802146_00.tab
# m32icl
# .tab
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031802146', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031802146', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 21, 46)}
# m32icl3l02_d2s_031802146_00.tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031802351_00.lbl
# This is a full URL.
# m32icl3l02_d2s_031802351_00.lbl
# m32icl
# .tab
# Full link: /mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031802351_00.tab
# This is a full URL.
# m32icl3l02_d2s_031802351_00.tab
# m32icl
# .tab
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031802351', 'version': '00', 'extension': '.tab'}
# {'mission': 'm32icl3l02', 'band': 'd2s', 'date_file': '031802351', 'version': '00', 'extension': '.tab', 'date_utc': datetime.datetime(2003, 6, 29, 23, 51)}
# m32icl3l02_d2s_031802351_00.tab
# Downloading https://pds-geosciences.wustl.edu/mex/mex-m-mrs-1_2_3-v1/mexmrs_0001/data/level02/closed_loop/ifms/dp2/m32icl3l02_d2s_031802351_00.tab
# Done.
# relevant IFMS files
# mex_kernels/m32icl3l02_d2s_031802351_00.tab
# mex_kernels/m32icl3l02_d2s_031802351_00.tab
